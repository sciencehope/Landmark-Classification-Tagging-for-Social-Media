# %% [markdown]
# # Convolutional Neural Networks
#
# ## Project: Write an Algorithm for Landmark Classification
#
# ### A simple app
#
# In this notebook we build a very simple app that uses our exported model.
#
# > <img src="static_images/icons/noun-info-2558213.png" alt="?" style="width:25px"/> Note how we are not importing anything from our source code (we do not use any module from the ``src`` directory). This is because the exported model, differently from the model weights, is a standalone serialization of our model and therefore it does not need anything else. You can ship that file to anybody, and as long as they can import ``torch``, they will be able to use your model. This is very important for releasing pytorch models to production.
#
# ### Test your app
# Go to a search engine for images (like Google Images) and search for images of some of the landmarks, like the Eiffel Tower, the Golden Gate Bridge, Machu Picchu and so on. Save a few examples locally, then upload them to your app to see how your model behaves!
#
# The app will show the top 5 classes that the model think are most relevant for the picture you have uploaded

# %%
# !pip install --upgrade ipywidgets
# Out:
# Collecting ipywidgets
#   Obtaining dependency information for ipywidgets from https://files.pythonhosted.org/packages/a3/af/9d5f256025100b578b11d7280e76fda349255666f752b618a613785cb58d/ipywidgets-8.0.7-py3-none-any.whl.metadata
#   Downloading ipywidgets-8.0.7-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\arnit\anaconda3\lib\site-packages (from ipywidgets) (6.19.2)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\arnit\anaconda3\lib\site-packages (from ipywidgets) (8.12.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\arnit\anaconda3\lib\site-packages (from ipywidgets) (5.7.1)
# Collecting widgetsnbextension~=4.0.7 (from ipywidgets)
#   Obtaining dependency information for widgetsnbextension~=4.0.7 from https://files.pythonhosted.org/packages/8e/d4/d31b12ac0b87e8cc9fdb6ea1eb6596de405eaaa2f25606aaa755d0eebbc0/widgetsnbextension-4.0.8-py3-none-any.whl.metadata
#   Downloading widgetsnbextension-4.0.8-py3-none-any.whl.metadata (1.6 kB)
# Collecting jupyterlab-widgets~=3.0.7 (from ipywidgets)
#   Obtaining dependency information for jupyterlab-widgets~=3.0.7 from https://files.pythonhosted.org/packages/74/5e/2475ac62faf2e342b2bf20b8d8e375f49400ecb38f52e4e0a7557eb1cedb/jupyterlab_widgets-3.0.8-py3-none-any.whl.metadata
#   Downloading jupyterlab_widgets-3.0.8-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: comm>=0.1.1 in c:\users\arnit\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets) (0.1.2)
# Requirement already satisfied: debugpy>=1.0 in c:\users\arnit\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets) (1.5.1)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\arnit\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets) (8.1.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\arnit\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets) (0.1.6)
# Requirement already satisfied: nest-asyncio in c:\users\arnit\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets) (1.5.6)
# Requirement already satisfied: packaging in c:\users\arnit\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets) (23.0)
# Requirement already satisfied: psutil in c:\users\arnit\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets) (5.9.0)
# Requirement already satisfied: pyzmq>=17 in c:\users\arnit\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets) (25.0.2)
# Requirement already satisfied: tornado>=6.1 in c:\users\arnit\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets) (6.2)
# Requirement already satisfied: backcall in c:\users\arnit\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.2.0)
# Requirement already satisfied: decorator in c:\users\arnit\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\arnit\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.18.1)
# Requirement already satisfied: pickleshare in c:\users\arnit\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in c:\users\arnit\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets) (3.0.36)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\arnit\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets) (2.15.1)
# Requirement already satisfied: stack-data in c:\users\arnit\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.2.0)
# Requirement already satisfied: colorama in c:\users\arnit\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.4.6)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\arnit\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\arnit\anaconda3\lib\site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets) (5.3.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\arnit\anaconda3\lib\site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets) (2.8.2)
# Requirement already satisfied: wcwidth in c:\users\arnit\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=6.1.0->ipywidgets) (0.2.5)
# Requirement already satisfied: executing in c:\users\arnit\anaconda3\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\arnit\anaconda3\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\arnit\anaconda3\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.2.2)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\arnit\anaconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets) (2.5.2)
# Requirement already satisfied: pywin32>=300 in c:\users\arnit\anaconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets) (305.1)
# Requirement already satisfied: six>=1.5 in c:\users\arnit\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets) (1.16.0)
# Downloading ipywidgets-8.0.7-py3-none-any.whl (138 kB)
#    ---------------------------------------- 0.0/138.3 kB ? eta -:--:--
#    -------- ------------------------------ 30.7/138.3 kB 660.6 kB/s eta 0:00:01
#    -------------------- ------------------ 71.7/138.3 kB 660.6 kB/s eta 0:00:01
#    ------------------------------ ------- 112.6/138.3 kB 731.4 kB/s eta 0:00:01
#    ------------------------------ ------- 112.6/138.3 kB 731.4 kB/s eta 0:00:01
#    -------------------------------------- 138.3/138.3 kB 630.8 kB/s eta 0:00:00
# Downloading jupyterlab_widgets-3.0.8-py3-none-any.whl (214 kB)
#    ---------------------------------------- 0.0/215.0 kB ? eta -:--:--
#    ----------- ---------------------------- 61.4/215.0 kB 1.7 MB/s eta 0:00:01
#    ----------------- ---------------------- 92.2/215.0 kB 1.3 MB/s eta 0:00:01
#    -------------------------------- ------- 174.1/215.0 kB 1.5 MB/s eta 0:00:01
#    ---------------------------------------- 215.0/215.0 kB 1.3 MB/s eta 0:00:00
# Downloading widgetsnbextension-4.0.8-py3-none-any.whl (2.3 MB)
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    - -------------------------------------- 0.1/2.3 MB 1.7 MB/s eta 0:00:02
#    -- ------------------------------------- 0.1/2.3 MB 1.4 MB/s eta 0:00:02
#    ---- ----------------------------------- 0.2/2.3 MB 1.6 MB/s eta 0:00:02
#    ---- ----------------------------------- 0.3/2.3 MB 1.5 MB/s eta 0:00:02
#    ------ --------------------------------- 0.4/2.3 MB 1.6 MB/s eta 0:00:02
#    ------- -------------------------------- 0.5/2.3 MB 1.6 MB/s eta 0:00:02
#    --------- ------------------------------ 0.5/2.3 MB 1.6 MB/s eta 0:00:02
#    ---------- ----------------------------- 0.6/2.3 MB 1.6 MB/s eta 0:00:02
#    ------------ --------------------------- 0.7/2.3 MB 1.7 MB/s eta 0:00:01
#    ------------ --------------------------- 0.7/2.3 MB 1.7 MB/s eta 0:00:01
#    -------------- ------------------------- 0.8/2.3 MB 1.5 MB/s eta 0:00:01
#    -------------- ------------------------- 0.9/2.3 MB 1.6 MB/s eta 0:00:01
#    ---------------- ----------------------- 0.9/2.3 MB 1.5 MB/s eta 0:00:01
#    ----------------- ---------------------- 1.0/2.3 MB 1.5 MB/s eta 0:00:01
#    ------------------ --------------------- 1.1/2.3 MB 1.5 MB/s eta 0:00:01
#    ------------------- -------------------- 1.1/2.3 MB 1.5 MB/s eta 0:00:01
#    -------------------- ------------------- 1.2/2.3 MB 1.5 MB/s eta 0:00:01
#    ----------------------- ---------------- 1.3/2.3 MB 1.6 MB/s eta 0:00:01
#    ------------------------ --------------- 1.4/2.3 MB 1.6 MB/s eta 0:00:01
#    -------------------------- ------------- 1.5/2.3 MB 1.6 MB/s eta 0:00:01
#    --------------------------- ------------ 1.6/2.3 MB 1.6 MB/s eta 0:00:01
#    ---------------------------- ----------- 1.7/2.3 MB 1.6 MB/s eta 0:00:01
#    ------------------------------ --------- 1.7/2.3 MB 1.6 MB/s eta 0:00:01
#    ------------------------------- -------- 1.8/2.3 MB 1.6 MB/s eta 0:00:01
#    --------------------------------- ------ 1.9/2.3 MB 1.6 MB/s eta 0:00:01
#    ---------------------------------- ----- 2.0/2.3 MB 1.6 MB/s eta 0:00:01
#    ------------------------------------ --- 2.1/2.3 MB 1.6 MB/s eta 0:00:01
#    ------------------------------------- -- 2.2/2.3 MB 1.6 MB/s eta 0:00:01
#    ---------------------------------------  2.3/2.3 MB 1.7 MB/s eta 0:00:01
#    ---------------------------------------- 2.3/2.3 MB 1.6 MB/s eta 0:00:00
# Installing collected packages: widgetsnbextension, jupyterlab-widgets, ipywidgets
# Successfully installed ipywidgets-8.0.7 jupyterlab-widgets-3.0.8 widgetsnbextension-4.0.8

# %%
# !jupyter nbextension enable --py widgetsnbextension
# Out:
# Enabling notebook extension jupyter-js-widgets/extension...
#       - Validating: ok

# %%
from ipywidgets import VBox, Button, FileUpload, Output, Label
from PIL import Image
from IPython.display import display
import io
import numpy as np
import torchvision
import torchvision.transforms as T
import torch

# Decide which model you want to use among the ones exported
learn_inf = torch.jit.load("checkpoints/transfer_exported.pt")

def on_click_classify(change):

    # Load image that has been uploaded
    fn = io.BytesIO(btn_upload.value[0]['content'])

    img = Image.open(fn)
    img.load()

    # Let's clear the previous output (if any)
    out_pl.clear_output()

    # Display the image
    with out_pl:

        ratio = img.size[0] / img.size[1]
        c = img.copy()
        c.thumbnail([ratio * 200, 200])
        display(c)

    # Transform to tensor
    timg = T.ToTensor()(img).unsqueeze_(0)

    # Calling the model
    softmax = learn_inf(timg).data.cpu().numpy().squeeze()
    
    # Get the indexes of the classes ordered by softmax
    # (larger first)
    idxs = np.argsort(softmax)[::-1]
    
    # Loop over the classes with the largest softmax
    for i in range(5):
        # Get softmax value
        p = softmax[idxs[i]]
    
        # Get class name
        landmark_name = learn_inf.class_names[idxs[i]]
        
        labels[i].value = f"{landmark_name} (prob: {p:.2f})"


# Putting back btn_upload to a widget for next cell
btn_upload = FileUpload()

btn_run = Button(description="Classify")
btn_run.on_click(on_click_classify)

labels = []
for _ in range(5):
    labels.append(Label())

out_pl = Output()
out_pl.clear_output()

wgs = [Label("Please upload a picture of a landmark"), btn_upload, btn_run, out_pl]
wgs.extend(labels)

VBox(wgs)
# Out:
# VBox(children=(Label(value='Please upload a picture of a landmark'), FileUpload(value=(), description='Upload'…

# %%
# !pip install voila
# Out:
# Collecting voila
#   Obtaining dependency information for voila from https://files.pythonhosted.org/packages/87/ec/52c49824ebccb62fd70168b35efe8b5f093ab960bfdea7b8e76432359a84/voila-0.4.1-py3-none-any.whl.metadata
#   Downloading voila-0.4.1-py3-none-any.whl.metadata (8.7 kB)
# Collecting jupyter-client<=7.4.1,>=6.1.3 (from voila)
#   Downloading jupyter_client-7.4.1-py3-none-any.whl (132 kB)
#      ---------------------------------------- 0.0/132.1 kB ? eta -:--:--
#      --------- ----------------------------- 30.7/132.1 kB 1.4 MB/s eta 0:00:01
#      ----------- ------------------------- 41.0/132.1 kB 495.5 kB/s eta 0:00:01
#      ------------------------- ----------- 92.2/132.1 kB 751.6 kB/s eta 0:00:01
#      --------------------------------- -- 122.9/132.1 kB 654.9 kB/s eta 0:00:01
#      ------------------------------------ 132.1/132.1 kB 651.6 kB/s eta 0:00:00
# Requirement already satisfied: jupyter-core>=4.11.0 in c:\users\arnit\anaconda3\lib\site-packages (from voila) (5.3.0)
# Requirement already satisfied: jupyter-server<2.0.0,>=1.18 in c:\users\arnit\anaconda3\lib\site-packages (from voila) (1.23.4)
# Requirement already satisfied: jupyterlab-server<3,>=2.3.0 in c:\users\arnit\anaconda3\lib\site-packages (from voila) (2.22.0)
# Requirement already satisfied: nbclient<0.8,>=0.4.0 in c:\users\arnit\anaconda3\lib\site-packages (from voila) (0.5.13)
# Requirement already satisfied: nbconvert<8,>=6.4.5 in c:\users\arnit\anaconda3\lib\site-packages (from voila) (6.5.4)
# Requirement already satisfied: traitlets<6,>=5.0.3 in c:\users\arnit\anaconda3\lib\site-packages (from voila) (5.7.1)
# Collecting websockets>=9.0 (from voila)
#   Downloading websockets-11.0.3-cp310-cp310-win_amd64.whl (124 kB)
#      ---------------------------------------- 0.0/124.7 kB ? eta -:--:--
#      ------------------- ------------------- 61.4/124.7 kB 3.2 MB/s eta 0:00:01
#      -------------------------------------  122.9/124.7 kB 1.4 MB/s eta 0:00:01
#      -------------------------------------- 124.7/124.7 kB 1.2 MB/s eta 0:00:00
# Requirement already satisfied: entrypoints in c:\users\arnit\anaconda3\lib\site-packages (from jupyter-client<=7.4.1,>=6.1.3->voila) (0.4)
# Requirement already satisfied: nest-asyncio>=1.5.4 in c:\users\arnit\anaconda3\lib\site-packages (from jupyter-client<=7.4.1,>=6.1.3->voila) (1.5.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\arnit\anaconda3\lib\site-packages (from jupyter-client<=7.4.1,>=6.1.3->voila) (2.8.2)
# Requirement already satisfied: pyzmq>=23.0 in c:\users\arnit\anaconda3\lib\site-packages (from jupyter-client<=7.4.1,>=6.1.3->voila) (25.0.2)
# Requirement already satisfied: tornado>=6.2 in c:\users\arnit\anaconda3\lib\site-packages (from jupyter-client<=7.4.1,>=6.1.3->voila) (6.2)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\arnit\anaconda3\lib\site-packages (from jupyter-core>=4.11.0->voila) (2.5.2)
# Requirement already satisfied: pywin32>=300 in c:\users\arnit\anaconda3\lib\site-packages (from jupyter-core>=4.11.0->voila) (305.1)
# Requirement already satisfied: anyio<4,>=3.1.0 in c:\users\arnit\anaconda3\lib\site-packages (from jupyter-server<2.0.0,>=1.18->voila) (3.5.0)
# Requirement already satisfied: argon2-cffi in c:\users\arnit\anaconda3\lib\site-packages (from jupyter-server<2.0.0,>=1.18->voila) (21.3.0)
# Requirement already satisfied: jinja2 in c:\users\arnit\anaconda3\lib\site-packages (from jupyter-server<2.0.0,>=1.18->voila) (3.1.2)
# Requirement already satisfied: nbformat>=5.2.0 in c:\users\arnit\anaconda3\lib\site-packages (from jupyter-server<2.0.0,>=1.18->voila) (5.7.0)
# Requirement already satisfied: packaging in c:\users\arnit\anaconda3\lib\site-packages (from jupyter-server<2.0.0,>=1.18->voila) (23.0)
# Requirement already satisfied: prometheus-client in c:\users\arnit\anaconda3\lib\site-packages (from jupyter-server<2.0.0,>=1.18->voila) (0.14.1)
# Requirement already satisfied: Send2Trash in c:\users\arnit\anaconda3\lib\site-packages (from jupyter-server<2.0.0,>=1.18->voila) (1.8.0)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\arnit\anaconda3\lib\site-packages (from jupyter-server<2.0.0,>=1.18->voila) (0.17.1)
# Requirement already satisfied: websocket-client in c:\users\arnit\anaconda3\lib\site-packages (from jupyter-server<2.0.0,>=1.18->voila) (0.58.0)
# Requirement already satisfied: pywinpty in c:\users\arnit\anaconda3\lib\site-packages (from jupyter-server<2.0.0,>=1.18->voila) (2.0.10)
# Requirement already satisfied: babel>=2.10 in c:\users\arnit\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.3.0->voila) (2.11.0)
# Requirement already satisfied: json5>=0.9.0 in c:\users\arnit\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.3.0->voila) (0.9.6)
# Requirement already satisfied: jsonschema>=4.17.3 in c:\users\arnit\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.3.0->voila) (4.17.3)
# Requirement already satisfied: requests>=2.28 in c:\users\arnit\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.3.0->voila) (2.29.0)
# Requirement already satisfied: lxml in c:\users\arnit\anaconda3\lib\site-packages (from nbconvert<8,>=6.4.5->voila) (4.9.2)
# Requirement already satisfied: beautifulsoup4 in c:\users\arnit\anaconda3\lib\site-packages (from nbconvert<8,>=6.4.5->voila) (4.12.2)
# Requirement already satisfied: bleach in c:\users\arnit\anaconda3\lib\site-packages (from nbconvert<8,>=6.4.5->voila) (4.1.0)
# Requirement already satisfied: defusedxml in c:\users\arnit\anaconda3\lib\site-packages (from nbconvert<8,>=6.4.5->voila) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\arnit\anaconda3\lib\site-packages (from nbconvert<8,>=6.4.5->voila) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\arnit\anaconda3\lib\site-packages (from nbconvert<8,>=6.4.5->voila) (2.1.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\arnit\anaconda3\lib\site-packages (from nbconvert<8,>=6.4.5->voila) (0.8.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\arnit\anaconda3\lib\site-packages (from nbconvert<8,>=6.4.5->voila) (1.5.0)
# Requirement already satisfied: pygments>=2.4.1 in c:\users\arnit\anaconda3\lib\site-packages (from nbconvert<8,>=6.4.5->voila) (2.15.1)
# Requirement already satisfied: tinycss2 in c:\users\arnit\anaconda3\lib\site-packages (from nbconvert<8,>=6.4.5->voila) (1.2.1)
# Requirement already satisfied: idna>=2.8 in c:\users\arnit\anaconda3\lib\site-packages (from anyio<4,>=3.1.0->jupyter-server<2.0.0,>=1.18->voila) (3.4)
# Requirement already satisfied: sniffio>=1.1 in c:\users\arnit\anaconda3\lib\site-packages (from anyio<4,>=3.1.0->jupyter-server<2.0.0,>=1.18->voila) (1.2.0)
# Requirement already satisfied: pytz>=2015.7 in c:\users\arnit\anaconda3\lib\site-packages (from babel>=2.10->jupyterlab-server<3,>=2.3.0->voila) (2022.7)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\arnit\anaconda3\lib\site-packages (from jsonschema>=4.17.3->jupyterlab-server<3,>=2.3.0->voila) (22.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\arnit\anaconda3\lib\site-packages (from jsonschema>=4.17.3->jupyterlab-server<3,>=2.3.0->voila) (0.18.0)
# Requirement already satisfied: fastjsonschema in c:\users\arnit\anaconda3\lib\site-packages (from nbformat>=5.2.0->jupyter-server<2.0.0,>=1.18->voila) (2.16.2)
# Requirement already satisfied: six>=1.5 in c:\users\arnit\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->jupyter-client<=7.4.1,>=6.1.3->voila) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\arnit\anaconda3\lib\site-packages (from requests>=2.28->jupyterlab-server<3,>=2.3.0->voila) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\arnit\anaconda3\lib\site-packages (from requests>=2.28->jupyterlab-server<3,>=2.3.0->voila) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\arnit\anaconda3\lib\site-packages (from requests>=2.28->jupyterlab-server<3,>=2.3.0->voila) (2023.5.7)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\arnit\anaconda3\lib\site-packages (from argon2-cffi->jupyter-server<2.0.0,>=1.18->voila) (21.2.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\arnit\anaconda3\lib\site-packages (from beautifulsoup4->nbconvert<8,>=6.4.5->voila) (2.4)
# Requirement already satisfied: webencodings in c:\users\arnit\anaconda3\lib\site-packages (from bleach->nbconvert<8,>=6.4.5->voila) (0.5.1)
# Requirement already satisfied: cffi>=1.0.1 in c:\users
kB/s eta 0:00:03
#    ------------------------- -------------- 3.5/5.5 MB 759.0 kB/s eta 0:00:03
#    -------------------------- ------------- 3.6/5.5 MB 759.9 kB/s eta 0:00:03
#    -------------------------- ------------- 3.6/5.5 MB 765.7 kB/s eta 0:00:03
#    -------------------------- ------------- 3.7/5.5 MB 766.8 kB/s eta 0:00:03
#    --------------------------- ------------ 3.7/5.5 MB 767.8 kB/s eta 0:00:03
#    --------------------------- ------------ 3.7/5.5 MB 766.7 kB/s eta 0:00:03
#    --------------------------- ------------ 3.8/5.5 MB 769.8 kB/s eta 0:00:03
#    --------------------------- ------------ 3.8/5.5 MB 768.4 kB/s eta 0:00:03
#    ---------------------------- ----------- 3.9/5.5 MB 771.7 kB/s eta 0:00:03
#    ---------------------------- ----------- 3.9/5.5 MB 770.3 kB/s eta 0:00:03
#    ---------------------------- ----------- 4.0/5.5 MB 771.2 kB/s eta 0:00:02
#    ----------------------------- ---------- 4.0/5.5 MB 780.1 kB/s eta 0:00:02
#    ------------------------------ --------- 4.1/5.5 MB 790.7 kB/s eta 0:00:02
#    ------------------------------ --------- 4.2/5.5 MB 798.9 kB/s eta 0:00:02
#    ------------------------------- -------- 4.3/5.5 MB 813.5 kB/s eta 0:00:02
#    ------------------------------- -------- 4.4/5.5 MB 815.9 kB/s eta 0:00:02
#    -------------------------------- ------- 4.4/5.5 MB 814.5 kB/s eta 0:00:02
#    -------------------------------- ------- 4.5/5.5 MB 820.6 kB/s eta 0:00:02
#    -------------------------------- ------- 4.5/5.5 MB 821.6 kB/s eta 0:00:02
#    --------------------------------- ------ 4.6/5.5 MB 823.9 kB/s eta 0:00:02
#    --------------------------------- ------ 4.6/5.5 MB 823.4 kB/s eta 0:00:02
#    ---------------------------------- ----- 4.7/5.5 MB 827.8 kB/s eta 0:00:01
#    ---------------------------------- ----- 4.7/5.5 MB 830.1 kB/s eta 0:00:01
#    ---------------------------------- ----- 4.8/5.5 MB 832.2 kB/s eta 0:00:01
#    ----------------------------------- ---- 4.8/5.5 MB 833.8 kB/s eta 0:00:01
#    ----------------------------------- ---- 4.9/5.5 MB 838.1 kB/s eta 0:00:01
#    ------------------------------------ --- 5.0/5.5 MB 843.0 kB/s eta 0:00:01
#    ------------------------------------ --- 5.0/5.5 MB 846.9 kB/s eta 0:00:01
#    ------------------------------------- -- 5.1/5.5 MB 852.2 kB/s eta 0:00:01
#    ------------------------------------- -- 5.2/5.5 MB 852.3 kB/s eta 0:00:01
#    -------------------------------------- - 5.2/5.5 MB 860.9 kB/s eta 0:00:01
#    -------------------------------------- - 5.3/5.5 MB 865.4 kB/s eta 0:00:01
#    ---------------------------------------  5.4/5.5 MB 871.0 kB/s eta 0:00:01
#    ---------------------------------------  5.5/5.5 MB 880.9 kB/s eta 0:00:01
#    ---------------------------------------- 5.5/5.5 MB 877.2 kB/s eta 0:00:00
# Installing collected packages: websockets, jupyter-client, voila
#   Attempting uninstall: jupyter-client
#     Found existing installation: jupyter_client 8.1.0
#     Uninstalling jupyter_client-8.1.0:
#       Successfully uninstalled jupyter_client-8.1.0
# Successfully installed jupyter-client-7.4.1 voila-0.4.1 websockets-11.0.3

# %% [markdown]
# ## (optional) Standalone app or web app
#
# You can run this notebook as a standalone app on your computer by following these steps:
#
# 1. Download this notebook in a directory on your machine
# 2. Download the model export (for example, ``checkpoints/transfer_exported.pt``) in a subdirectory called ``checkpoints`` within the directory where you save the app.ipynb notebook
# 3. Install voila if you don't have it already (``pip install voila``)
# 4. Run your app: ``voila app.ipynb --show_tracebacks=True``
# 5. Customize your notebook to make your app prettier and rerun voila
#
# You can also deploy this app as a website using Binder: https://voila.readthedocs.io/en/stable/deploy.html#deployment-on-binder

# %% [markdown]
# # Create your submission archive
#
# Now that you are done with your project, please run the following cell. It will generate a file containing all the code you have written, as well as the notebooks. Please submit that file to complete your project

# %%
# !python src/create_submit_pkg.py
# Out:
# executing: jupyter nbconvert --to html app.ipynb
# executing: jupyter nbconvert --to html cnn_from_scratch.ipynb
# executing: jupyter nbconvert --to html transfer_learning.ipynb
# Adding files to submission_2023-07-24T11h44m.tar.gz
# src\create_submit_pkg.py
# src\data.py
# src\helpers.py
# src\model.py
# src\optimization.py
# src\predictor.py
# src\train.py
# src\transfer.py
# src\__init__.py
# app.ipynb
# cnn_from_scratch.ipynb
# transfer_learning.ipynb
# app.html
# cnn_from_scratch.html
# transfer_learning.html
#
# ----------------------------------------------------------------
# Done. Please submit the file submission_2023-07-24T11h44m.tar.gz
# ----------------------------------------------------------------
# [NbConvertApp] Converting notebook app.ipynb to html
# [NbConvertApp] Writing 623227 bytes to app.html
# [NbConvertApp] Converting notebook cnn_from_scratch.ipynb to html
# [NbConvertApp] Writing 2797017 bytes to cnn_from_scratch.html
# [NbConvertApp] Converting notebook transfer_learning.ipynb to html
# [NbConvertApp] Writing 1664448 bytes to transfer_learning.html
