# %% [markdown]
# # Convolutional Neural Networks
#
# ## Project: Write an Algorithm for Landmark Classification
#
#
# ### Introduction
#
# The project folder has the following structure:
#
# * In the main directory you have this notebook, `cnn_from_scratch.ipynb`, that contains the instruction and some questions you will have to answer. Follow this notebook and complete the required sections in order.
#
# * In the `src/` directory you have several source files. As instructed in this notebook, you will open and complete those files, then come back to this notebook to execute some tests that will verify what you have done. While these tests don't guarantee that your work is bug-free, they will help you finding the most obvious problems so you will be able to proceed to the next step with confidence.
#
# * Sometimes you will need to restart the notebook. If you do so, remember to execute also the cells containing the code you have already completed starting from the top, before you move on.
#
# In addition to implementing code, there will be questions that you must answer which relate to the project and your implementation. Each section where you will answer a question is preceded by a **'Question'** header. Carefully read each question and provide thorough answers in the following text boxes that begin with **'Answer:'**. Your project submission will be evaluated based on your answers to each of the questions and the implementation you provide.
#
# > <img src="static_images/icons/noun-info-2558213.png" alt="?" style="width:25px"/> Code and Markdown cells can be executed using the **Shift + Enter** keyboard shortcut.  Markdown cells can be edited by double-clicking the cell to enter edit mode.
#
# The rubric contains _optional_ "Stand Out Suggestions" for enhancing the project beyond the minimum requirements. If you decide to pursue the "Stand Out Suggestions", you should include the code in this Jupyter notebook.
#
# ### Designing and training a CNN from scratch
#
# In this notebook, you will create a CNN that classifies landmarks.  You must create your CNN _from scratch_ (so, you can't use transfer learning _yet_!), and you must attain a test accuracy of at least 50%.
#
# Although 50% may seem low at first glance, it seems more reasonable after realizing how difficult of a problem this is. Many times, an image that is taken at a landmark captures a fairly mundane image of an animal or plant, like in the following picture.
#
# <img src="static_images/train/00.Haleakala_National_Park/084c2aa50d0a9249.jpg" alt="Bird in Haleakalā National Park" style="width: 400px;"/>
#
# Just by looking at that image alone, would you have been able to guess that it was taken at the Haleakalā National Park in Hawaii?
#
# An accuracy of 50% is significantly better than random guessing, which would provide an accuracy of just 2% (100% / 50 classes). In Step 2 of this notebook, you will have the opportunity to greatly improve accuracy by using transfer learning to create a CNN.
#
# Experiment with different architectures, hyperparameters, training strategies, and trust your intuition.  And, of course, have fun!
#
# ---
# ## <img src="static_images/icons/noun-advance-2109145.png" alt=">" style="width:50px"/> Step 0: Setting up
#
# The following cells make sure that your environment is setup correctly, download the data if you don't have it already, and also check that your GPU is available and ready to go. You have to execute them every time you restart your notebook.

# %%
# !pip install -U pytest
# Out:
# Requirement already satisfied: pytest in c:\users\annicet\anaconda3\envs\udacity\lib\site-packages (7.1.1)
# Collecting pytest
#   Obtaining dependency information for pytest from https://files.pythonhosted.org/packages/df/d0/e192c4275aecabf74faa1aacd75ef700091913236ec78b1a98f62a2412ee/pytest-7.4.2-py3-none-any.whl.metadata
#   Downloading pytest-7.4.2-py3-none-any.whl.metadata (7.9 kB)
# Requirement already satisfied: iniconfig in c:\users\annicet\appdata\roaming\python\python39\site-packages (from pytest) (2.0.0)
# Requirement already satisfied: packaging in c:\users\annicet\anaconda3\envs\udacity\lib\site-packages (from pytest) (23.1)
# Requirement already satisfied: pluggy<2.0,>=0.12 in c:\users\annicet\anaconda3\envs\udacity\lib\site-packages (from pytest) (1.3.0)
# Requirement already satisfied: exceptiongroup>=1.0.0rc8 in c:\users\annicet\anaconda3\envs\udacity\lib\site-packages (from pytest) (1.0.4)
# Requirement already satisfied: tomli>=1.0.0 in c:\users\annicet\anaconda3\envs\udacity\lib\site-packages (from pytest) (2.0.1)
# Requirement already satisfied: colorama in c:\users\annicet\anaconda3\envs\udacity\lib\site-packages (from pytest) (0.4.6)
# Downloading pytest-7.4.2-py3-none-any.whl (324 kB)
#    ---------------------------------------- 0.0/324.5 kB ? eta -:--:--
#    ---------------------------------------- 0.0/324.5 kB ? eta -:--:--
#    ---------------------------------------- 0.0/324.5 kB ? eta -:--:--
#    ---------------------------------------- 0.0/324.5 kB ? eta -:--:--
#    ---------------------------------------- 0.0/324.5 kB ? eta -:--:--
#    ---------------------------------------- 0.0/324.5 kB ? eta -:--:--
#    ---------------------------------------- 0.0/324.5 kB ? eta -:--:--
#    ---------------------------------------- 0.0/324.5 kB ? eta -:--:--
#    ---------------------------------------- 0.0/324.5 kB ? eta -:--:--
#    ---------------------------------------- 0.0/324.5 kB ? eta -:--:--
#    ---------------------------------------- 0.0/324.5 kB ? eta -:--:--
#    - -------------------------------------- 10.2/324.5 kB ? eta -:--:--
#    - -------------------------------------- 10.2/324.5 kB ? eta -:--:--
#    - -------------------------------------- 10.2/324.5 kB ? eta -:--:--
#    - -------------------------------------- 10.2/324.5 kB ? eta -:--:--
#    - -------------------------------------- 10.2/324.5 kB ? eta -:--:--
#    --- ------------------------------------ 30.7/324.5 kB 87.5 kB/s eta 0:00:04
#    --- ------------------------------------ 30.7/324.5 kB 87.5 kB/s eta 0:00:04
#    --- ------------------------------------ 30.7/324.5 kB 87.5 kB/s eta 0:00:04
#    --- ------------------------------------ 30.7/324.5 kB 87.5 kB/s eta 0:00:04
#    --- ------------------------------------ 30.7/324.5 kB 87.5 kB/s eta 0:00:04
#    --- ------------------------------------ 30.7/324.5 kB 87.5 kB/s eta 0:00:04
#    --- ------------------------------------ 30.7/324.5 kB 87.5 kB/s eta 0:00:04
#    ----- ---------------------------------- 41.0/324.5 kB 59.6 kB/s eta 0:00:05
#    ----- ---------------------------------- 41.0/324.5 kB 59.6 kB/s eta 0:00:05
#    ----- ---------------------------------- 41.0/324.5 kB 59.6 kB/s eta 0:00:05
#    ----- ---------------------------------- 41.0/324.5 kB 59.6 kB/s eta 0:00:05
#    ----- ---------------------------------- 41.0/324.5 kB 59.6 kB/s eta 0:00:05
#    ------- -------------------------------- 61.4/324.5 kB 66.9 kB/s eta 0:00:04
#    ------- -------------------------------- 61.4/324.5 kB 66.9 kB/s eta 0:00:04
#    ------- -------------------------------- 61.4/324.5 kB 66.9 kB/s eta 0:00:04
#    ------- -------------------------------- 61.4/324.5 kB 66.9 kB/s eta 0:00:04
#    -------- ------------------------------- 71.7/324.5 kB 64.5 kB/s eta 0:00:04
#    -------- ------------------------------- 71.7/324.5 kB 64.5 kB/s eta 0:00:04
#    -------- ------------------------------- 71.7/324.5 kB 64.5 kB/s eta 0:00:04
#    -------- ------------------------------- 71.7/324.5 kB 64.5 kB/s eta 0:00:04
#    -------- ------------------------------- 71.7/324.5 kB 64.5 kB/s eta 0:00:04
#    -------- ------------------------------- 71.7/324.5 kB 64.5 kB/s eta 0:00:04
#    ----------- ---------------------------- 92.2/324.5 kB 67.2 kB/s eta 0:00:04
#    ----------- ---------------------------- 92.2/324.5 kB 67.2 kB/s eta 0:00:04
#    ----------- ---------------------------- 92.2/324.5 kB 67.2 kB/s eta 0:00:04
#    ----------- ---------------------------- 92.2/324.5 kB 67.2 kB/s eta 0:00:04
#    ---------------------------------- ---- 286.7/324.5 kB 58.2 kB/s eta 0:00:01
#    ---------------------------------- ---- 286.7/324.5 kB 58.2 kB/s eta 0:00:01
#    ---------------------------------- ---- 286.7/324.5 kB 58.2 kB/s eta 0:00:01
#    ---------------------------------- ---- 286.7/324.5 kB 58.2 kB/s eta 0:00:01
#    ---------------------------------- ---- 286.7/324.5 kB 58.2 kB/s eta 0:00:01
#    ---------------------------------- ---- 286.7/324.5 kB 58.2 kB/s eta 0:00:01
#    ------------------------------------ -- 307.2/324.5 kB 58.8 kB/s eta 0:00:01
#    ------------------------------------ -- 307.2/324.5 kB 58.8 kB/s eta 0:00:01
#    ------------------------------------ -- 307.2/324.5 kB 58.8 kB/s eta 0:00:01
#    ------------------------------------ -- 307.2/324.5 kB 58.8 kB/s eta 0:00:01
#    --------------------------------------- 324.5/324.5 kB 60.0 kB/s eta 0:00:00
# Installing collected packages: pytest
#   Attempting uninstall: pytest
#     Found existing installation: pytest 7.1.1
#     Uninstalling pytest-7.1.1:
#       Successfully uninstalled pytest-7.1.1
# Successfully installed pytest-7.4.2

# %%
# !pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in c:\users\annicet\anaconda3\envs\udacity\lib\site-packages (23.2.1)

# %%
# !pip cache purge
# Out:
# Files removed: 5

# %%
# Install requirements
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: opencv-python-headless==4.5.3.56 in c:\users\annicet\appdata\roaming\python\python39\site-packages (from -r requirements.txt (line 1)) (4.5.3.56)
# Requirement already satisfied: matplotlib==3.4.3 in c:\users\annicet\appdata\roaming\python\python39\site-packages (from -r requirements.txt (line 2)) (3.4.3)
# Requirement already satisfied: numpy==1.21.2 in c:\users\annicet\anaconda3\envs\udacity\lib\site-packages (from -r requirements.txt (line 3)) (1.21.2)
# Requirement already satisfied: pillow in c:\users\annicet\anaconda3\envs\udacity\lib\site-packages (from -r requirements.txt (line 4)) (9.4.0)
# Requirement already satisfied: bokeh==2.1.1 in c:\users\annicet\appdata\roaming\python\python39\site-packages (from -r requirements.txt (line 5)) (2.1.1)
# Requirement already satisfied: torch==1.11.0 in c:\users\annicet\anaconda3\envs\udacity\lib\site-packages (from -r requirements.txt (line 6)) (1.11.0)
# Requirement already satisfied: torchvision==0.12.0 in c:\users\annicet\anaconda3\envs\udacity\lib\site-packages (from -r requirements.txt (line 7)) (0.12.0)
# Requirement already satisfied: tqdm==4.63.0 in c:\users\annicet\anaconda3\envs\udacity\lib\site-packages (from -r requirements.txt (line 8)) (4.63.0)
# Requirement already satisfied: ipywidgets==7.6.5 in c:\users\annicet\appdata\roaming\python\python39\site-packages (from -r requirements.txt (line 9)) (7.6.5)
# Requirement already satisfied: livelossplot==0.5.4 in c:\users\annicet\appdata\roaming\python\python39\site-packages (from -r requirements.txt (line 10)) (0.5.4)
# Collecting pytest==7.1.1 (from -r requirements.txt (line 11))
#   Downloading pytest-7.1.1-py3-none-any.whl (297 kB)
#      ---------------------------------------- 0.0/297.0 kB ? eta -:--:--
#      ---------------------------------------- 0.0/297.0 kB ? eta -:--:--
#      ---------------------------------------- 0.0/297.0 kB ? eta -:--:--
#      - -------------------------------------- 10.2/297.0 kB ? eta -:--:--
#      - -------------------------------------- 10.2/297.0 kB ? eta -:--:--
#      - -------------------------------------- 10.2/297.0 kB ? eta -:--:--
#      - -------------------------------------- 10.2/297.0 kB ? eta -:--:--
#      --- --------------------------------- 30.7/297.0 kB 119.1 kB/s eta 0:00:03
#      --- --------------------------------- 30.7/297.0 kB 119.1 kB/s eta 0:00:03
#      ----- ------------------------------- 41.0/297.0 kB 108.9 kB/s eta 0:00:03
#      ----- ------------------------------- 41.0/297.0 kB 108.9 kB/s eta 0:00:03
#      ----- ------------------------------- 41.0/297.0 kB 108.9 kB/s eta 0:00:03
c:\users\annicet\anaconda3\envs\udacity\lib\site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets==7.6.5->-r requirements.txt (line 9)) (0.4)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\annicet\anaconda3\envs\udacity\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel>=4.5.1->ipywidgets==7.6.5->-r requirements.txt (line 9)) (3.10.0)
# Requirement already satisfied: pywin32>=300 in c:\users\annicet\anaconda3\envs\udacity\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel>=4.5.1->ipywidgets==7.6.5->-r requirements.txt (line 9)) (305.1)
# Requirement already satisfied: argon2-cffi in c:\users\annicet\anaconda3\envs\udacity\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (21.3.0)
# Requirement already satisfied: nbconvert>=5 in c:\users\annicet\anaconda3\envs\udacity\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (6.5.4)
# Requirement already satisfied: Send2Trash>=1.8.0 in c:\users\annicet\anaconda3\envs\udacity\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (1.8.0)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\annicet\anaconda3\envs\udacity\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (0.17.1)
# Requirement already satisfied: prometheus-client in c:\users\annicet\anaconda3\envs\udacity\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (0.14.1)
# Requirement already satisfied: nbclassic>=0.4.7 in c:\users\annicet\anaconda3\envs\udacity\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (0.5.5)
# Requirement already satisfied: wcwidth in c:\users\annicet\anaconda3\envs\udacity\lib\site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=4.0.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (0.2.5)
# Requirement already satisfied: executing in c:\users\annicet\anaconda3\envs\udacity\lib\site-packages (from stack-data->ipython>=4.0.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\annicet\anaconda3\envs\udacity\lib\site-packages (from stack-data->ipython>=4.0.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\annicet\anaconda3\envs\udacity\lib\site-packages (from stack-data->ipython>=4.0.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (0.2.2)
# Requirement already satisfied: jupyter-server>=1.8 in c:\users\annicet\anaconda3\envs\udacity\lib\site-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (1.23.4)
# Requirement already satisfied: notebook-shim>=0.1.0 in c:\users\annicet\anaconda3\envs\udacity\lib\site-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (0.2.2)
# Requirement already satisfied: lxml in c:\users\annicet\anaconda3\envs\udacity\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (4.9.2)
# Requirement already satisfied: beautifulsoup4 in c:\users\annicet\anaconda3\envs\udacity\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (4.12.2)
# Requirement already satisfied: bleach in c:\users\annicet\anaconda3\envs\udacity\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (4.1.0)
# Requirement already satisfied: defusedxml in c:\users\annicet\anaconda3\envs\udacity\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\annicet\anaconda3\envs\udacity\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (0.1.2)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\annicet\anaconda3\envs\udacity\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (0.8.4)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\annicet\anaconda3\envs\udacity\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (0.5.13)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\annicet\anaconda3\envs\udacity\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (1.5.0)
# Requirement already satisfied: tinycss2 in c:\users\annicet\anaconda3\envs\udacity\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (1.2.1)
# Requirement already satisfied: pywinpty>=1.1.0 in c:\users\annicet\anaconda3\envs\udacity\lib\site-packages (from terminado>=0.8.3->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (2.0.10)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\annicet\anaconda3\envs\udacity\lib\site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (21.2.0)
# Requirement already satisfied: anyio<4,>=3.1.0 in c:\users\annicet\anaconda3\envs\udacity\lib\site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (3.5.0)
# Requirement already satisfied: websocket-client in c:\users\annicet\anaconda3\envs\udacity\lib\site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (0.58.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\annicet\anaconda3\envs\udacity\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (1.15.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\annicet\anaconda3\envs\udacity\lib\site-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (2.4)
# Requirement already satisfied: webencodings in c:\users\annicet\anaconda3\envs\udacity\lib\site-packages (from bleach->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (0.5.1)
# Requirement already satisfied: sniffio>=1.1 in c:\users\annicet\anaconda3\envs\udacity\lib\site-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (1.2.0)
# Requirement already satisfied: pycparser in c:\users\annicet\anaconda3\envs\udacity\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (2.21)
# Installing collected packages: pytest
#   Attempting uninstall: pytest
#     Found existing installation: pytest 7.4.2
#     Uninstalling pytest-7.4.2:
#       Successfully uninstalled pytest-7.4.2
# Successfully installed pytest-7.1.1

# %%
from src.helpers import setup_env

# If running locally, this will download dataset (make sure you have at 
# least 2 Gb of space on your hard drive)
setup_env()
# Out:
# GPU available
# Dataset already downloaded. If you need to re-download, please delete the directory landmark_images
# Reusing cached mean and std

# %% [markdown]
# ---
# ## <img src="static_images/icons/noun-advance-2109145.png" alt=">" style="width:50px"/> Step 1: Data
#
# In this and the following steps we are going to complete some code, and then execute some tests to make sure the code works as intended.
#
# Open the file `src/data.py`. It contains a function called `get_data_loaders`. Read the function and complete all the parts marked by `YOUR CODE HERE`. Once you have finished, test that your implementation is correct by executing the following cell (see below for what to do if a test fails):

# %%
# !pytest -vv src/data.py -k data_loaders
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.9.18, pytest-7.1.1, pluggy-1.3.0 -- C:\Users\annicet\anaconda3\envs\udacity\python.exe
# cachedir: .pytest_cache
# rootdir: C:\Users\annicet\Projects\Landmark-Classification-Tagging-for-Social-Media
# plugins: anyio-3.5.0
# collecting ... collected 4 items / 1 deselected / 3 selected
#
# src/data.py::test_data_loaders_keys PASSED                               [ 33%]
# src/data.py::test_data_loaders_output_type PASSED                        [ 66%]
# src/data.py::test_data_loaders_output_shape PASSED                       [100%]
#
# ============================== warnings summary ===============================
# ..\..\AppData\Roaming\Python\Python39\site-packages\matplotlib\__init__.py:152
# ..\..\AppData\Roaming\Python\Python39\site-packages\matplotlib\__init__.py:152
# ..\..\AppData\Roaming\Python\Python39\site-packages\matplotlib\__init__.py:152
# ..\..\AppData\Roaming\Python\Python39\site-packages\matplotlib\__init__.py:152
# ..\..\AppData\Roaming\Python\Python39\site-packages\matplotlib\__init__.py:152
#   C:\Users\annicet\AppData\Roaming\Python\Python39\site-packages\matplotlib\__init__.py:152: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#     if LooseVersion(module.__version__) < minver:
#
# ..\..\anaconda3\envs\udacity\lib\site-packages\setuptools\_distutils\version.py:345
# ..\..\anaconda3\envs\udacity\lib\site-packages\setuptools\_distutils\version.py:345
# ..\..\anaconda3\envs\udacity\lib\site-packages\setuptools\_distutils\version.py:345
# ..\..\anaconda3\envs\udacity\lib\site-packages\setuptools\_distutils\version.py:345
# ..\..\anaconda3\envs\udacity\lib\site-packages\setuptools\_distutils\version.py:345
#   C:\Users\annicet\anaconda3\envs\udacity\lib\site-packages\setuptools\_distutils\version.py:345: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#     other = LooseVersion(other)
#
# -- Docs: https://docs.pytest.org/en/stable/how-to/capture-warnings.html
# ================ 3 passed, 1 deselected, 10 warnings in 1.60s =================

# %% [markdown]
# You should see something like:
# ```
# src/data.py::test_data_loaders_keys PASSED                               [ 33%]
# src/data.py::test_data_loaders_output_type PASSED                        [ 66%]
# src/data.py::test_data_loaders_output_shape PASSED                       [100%]
#
# ======================= 3 passed, 1 deselected in 1.81s ========================
# ```
# If all the tests are `PASSED`, you can move to the next section.
#
# > <img src="static_images/icons/noun-info-2558213.png" alt="?" style="width:25px"/> **What to do if tests fail**
# When a test fails, `pytest` will mark it as `FAILED` as opposed to `PASSED`, and will print a lot of useful output, including a message that should tell you what the problem is. For example, this is the output of a failed test:
# > ```
# >    def test_data_loaders_keys(data_loaders):
# >
# >       assert set(data_loaders.keys()) == {"train", "valid", "test"}
# E       AssertionError: assert {'tes', 'train', 'valid'} == {'test', 'train', 'valid'}
# E         Extra items in the left set:
# E         'tes'
# E         Full diff:
# E         - {'test', 'train', 'valid'}
# E         + {'tes', 'train', 'valid'}
# E         ?                          +++++++
# >
# > src/data.py:171: AssertionError
# -------------- Captured stdout setup ----------------------------------------------
# Reusing cached mean and std for landmark_images
# Dataset mean: tensor([0.4638, 0.4725, 0.4687]), std: tensor([0.2699, 0.2706, 0.3018])
# =========== short test summary info ===============================================
# FAILED src/data.py::test_data_loaders_keys - AssertionError: The keys of the data_loaders dictionary should be train, valid and test
# > ```
# > In the `short test summary info` you can see a short description of the problem. In this case, the dictionary we are returning has the wrong keys. Going above a little, you can see that the test expects `{'test', 'train', 'valid'}` while we are returning `{'tes', 'train', 'valid'}` (there is a missing `t`). So we can go back to our function, fix that problem and test again.
# >
# > In other cases, you might get an error like:
# > ```
#     def _conv_forward(self, input: Tensor, weight: Tensor, bias: Optional[Tensor]):
#         if self.padding_mode != 'zeros':
#             return F.conv2d(F.pad(input, self._reversed_padding_repeated_twice, mode=self.padding_mode),
#                             weight, bias, self.stride,
#                             _pair(0), self.dilation, self.groups)
#         return F.conv2d(input, weight, bias, self.stride,
# >                       self.padding, self.dilation, self.groups)
# E       RuntimeError: Input type (torch.cuda.FloatTensor) and weight type (torch.FloatTensor) should be the same
# >
# > ../../../../miniconda3/envs/udacity_starter/lib/python3.7/site-packages/torch/nn/modules/conv.py:440: RuntimeError
# > ```
# > Looking at the stack trace you should be able to understand what it is going on. In this case, we forgot to add a `.cuda()` to some tensor. For example, the model is on the GPU, but the data aren't.

# %% [markdown]
# <img src="static_images/icons/noun-question-mark-869751.png" alt="?" style="width:25px"/> **Question:** Describe your chosen procedure for preprocessing the data.
# - How does your code resize the images (by cropping, stretching, etc)?  What size did you pick for the input tensor, and why?
# - Did you decide to augment the dataset?  If so, how (through translations, flips, rotations, etc)?  If not, why not?

# %% [markdown]
# <img src="static_images/icons/noun-answer-3361020.png" alt=">" style="width:25px"/> **Answer**: My code first resizes the image to 256 and then crops to 224. I picked 224 as the input size because it is the recommended input size for using pytorch's pre-trained models. I did decide to augment the dataset via RandAugment, a typical set of augmentations for natural images. I added this augmentation with the goal of improving my model's robustness, thus improving test accuracy.

# %% [markdown]
# ### Visualize a Batch of Training Data
#
# Go back to `src/data.py` and complete the function `visualize_one_batch` in all places with the `YOUR CODE HERE` marker. After you're done, execute the following cell and make sure the test `src/data.py::test_visualize_one_batch` is `PASSED`:

# %%
# !pytest -vv src/data.py -k visualize_one_batch
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.9.18, pytest-7.1.1, pluggy-1.3.0 -- C:\Users\annicet\anaconda3\envs\udacity\python.exe
# cachedir: .pytest_cache
# rootdir: C:\Users\annicet\Projects\Landmark-Classification-Tagging-for-Social-Media
# plugins: anyio-3.5.0
# collecting ... collected 4 items / 3 deselected / 1 selected
#
# src/data.py::test_visualize_one_batch PASSED                             [100%]
#
# ============================== warnings summary ===============================
# ..\..\AppData\Roaming\Python\Python39\site-packages\matplotlib\__init__.py:152
# ..\..\AppData\Roaming\Python\Python39\site-packages\matplotlib\__init__.py:152
# ..\..\AppData\Roaming\Python\Python39\site-packages\matplotlib\__init__.py:152
# ..\..\AppData\Roaming\Python\Python39\site-packages\matplotlib\__init__.py:152
# ..\..\AppData\Roaming\Python\Python39\site-packages\matplotlib\__init__.py:152
#   C:\Users\annicet\AppData\Roaming\Python\Python39\site-packages\matplotlib\__init__.py:152: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#     if LooseVersion(module.__version__) < minver:
#
# ..\..\anaconda3\envs\udacity\lib\site-packages\setuptools\_distutils\version.py:345
# ..\..\anaconda3\envs\udacity\lib\site-packages\setuptools\_distutils\version.py:345
# ..\..\anaconda3\envs\udacity\lib\site-packages\setuptools\_distutils\version.py:345
# ..\..\anaconda3\envs\udacity\lib\site-packages\setuptools\_distutils\version.py:345
# ..\..\anaconda3\envs\udacity\lib\site-packages\setuptools\_distutils\version.py:345
#   C:\Users\annicet\anaconda3\envs\udacity\lib\site-packages\setuptools\_distutils\version.py:345: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#     other = LooseVersion(other)
#
# -- Docs: https://docs.pytest.org/en/stable/how-to/capture-warnings.html
# ================ 1 passed, 3 deselected, 10 warnings in 1.12s =================

# %% [markdown]
# We can now use the code we just completed to get a batch of images from your train data loader and look at them.
#
# Visualizing the output of your data loader is a great way to ensure that your data loading and preprocessing (including transforms such as rotations, translations, color transforms...) are working as expected.

# %%
# %matplotlib inline
from src.data import visualize_one_batch, get_data_loaders

# use get_data_loaders to get the data_loaders dictionary. Use a batch_size
# of 5, a validation size of 0.01 and num_workers=-1 (all CPUs)
data_loaders = get_data_loaders(batch_size = 5, valid_size = 0.01, num_workers = 0)

visualize_one_batch(data_loaders)
# Out:
# Reusing cached mean and std
# Dataset mean: tensor([0.4638, 0.4725, 0.4687]), std: tensor([0.2699, 0.2706, 0.3018])
# Reusing cached mean and std

# %% [markdown]
# ---
# ## <img src="static_images/icons/noun-advance-2109145.png" alt=">" style="width:50px"/> Step 2: Define model
#
# Open `src/model.py` and complete the `MyModel` class filling in all the `YOUR CODE HERE` sections. After you're done, execute the following test and make sure it passes:

# %%
# !pytest -vv src/model.py
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.9.18, pytest-7.1.1, pluggy-1.3.0 -- C:\Users\annicet\anaconda3\envs\udacity\python.exe
# cachedir: .pytest_cache
# rootdir: C:\Users\annicet\Projects\Landmark-Classification-Tagging-for-Social-Media
# plugins: anyio-3.5.0
# collecting ... collected 1 item
#
# src/model.py::test_model_construction PASSED                             [100%]
#
# ============================== warnings summary ===============================
# src/model.py::test_model_construction
# src/model.py::test_model_construction
# src/model.py::test_model_construction
# src/model.py::test_model_construction
# src/model.py::test_model_construction
#   C:\Users\annicet\AppData\Roaming\Python\Python39\site-packages\matplotlib\__init__.py:152: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#     if LooseVersion(module.__version__) < minver:
#
# src/model.py::test_model_construction
# src/model.py::test_model_construction
# src/model.py::test_model_construction
# src/model.py::test_model_construction
# src/model.py::test_model_construction
#   C:\Users\annicet\anaconda3\envs\udacity\lib\site-packages\setuptools\_distutils\version.py:345: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#     other = LooseVersion(other)
#
# -- Docs: https://docs.pytest.org/en/stable/how-to/capture-warnings.html
# ======================= 1 passed, 10 warnings in 1.09s ========================

# %% [markdown]
# <img src="static_images/icons/noun-question-mark-869751.png" alt="?" style="width:25px"/> **Question**: Outline the steps you took to get to your final CNN architecture and your reasoning at each step.

# %% [markdown]
# <img src="static_images/icons/noun-answer-3361020.png" alt=">" style="width:25px"/> __Answer:__ I decided to use 5 convolutional layers so that my model could be sufficiently expressive. I used dropout, batch normalization layers to reduce my model's tendency to overfit the training data. I made my model output a 50-dimensional vector to match with the 50 available landmark classes.

# %% [markdown]
# ---
# ## <img src="static_images/icons/noun-advance-2109145.png" alt=">" style="width:50px"/> Step 3: define loss and optimizer
#
# Open `src/optimization.py` and complete the `get_loss` function, then execute the test and make sure it passes:

# %%
# !pytest -vv src/optimization.py -k get_loss
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.9.18, pytest-7.1.1, pluggy-1.3.0 -- C:\Users\annicet\anaconda3\envs\udacity\python.exe
# cachedir: .pytest_cache
# rootdir: C:\Users\annicet\Projects\Landmark-Classification-Tagging-for-Social-Media
# plugins: anyio-3.5.0
# collecting ... collected 7 items / 6 deselected / 1 selected
#
# src/optimization.py::test_get_loss PASSED                                [100%]
#
# ======================= 1 passed, 6 deselected in 0.50s =======================

# %% [markdown]
# Then, in the same file, complete the `get_optimizer` function then execute its tests, and make sure they all pass:

# %%
# !pytest -vv src/optimization.py -k get_optimizer
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.9.18, pytest-7.1.1, pluggy-1.3.0 -- C:\Users\annicet\anaconda3\envs\udacity\python.exe
# cachedir: .pytest_cache
# rootdir: C:\Users\annicet\Projects\Landmark-Classification-Tagging-for-Social-Media
# plugins: anyio-3.5.0
# collecting ... collected 7 items / 1 deselected / 6 selected
#
# src/optimization.py::test_get_optimizer_type PASSED                      [ 16%]
# src/optimization.py::test_get_optimizer_is_linked_with_model PASSED      [ 33%]
# src/optimization.py::test_get_optimizer_returns_adam PASSED              [ 50%]
# src/optimization.py::test_get_optimizer_sets_learning_rate PASSED        [ 66%]
# src/optimization.py::test_get_optimizer_sets_momentum PASSED             [ 83%]
# src/optimization.py::test_get_optimizer_sets_weight_decat PASSED         [100%]
#
# ======================= 6 passed, 1 deselected in 0.50s =======================

# %% [markdown]
# ---
# ## <img src="static_images/icons/noun-advance-2109145.png" alt=">" style="width:50px"/> Step 4: Train and Validate the Model
#
# > <img src="static_images/icons/noun-info-2558213.png" alt="?" style="width:25px"/> Testing ML code is notoriously difficult. The tests in this section merely exercise the functions you are completing, so it will help you catching glaring problems but it won't guarantee that your training code is bug-free. If you see that your loss is not decreasing, for example, that's a sign of a bug or of a flawed model design. Use your judgement.
#
# Open `src/train.py` and complete the `train_one_epoch` function, then run the tests:

# %%
# !pytest -vv src/train.py -k train_one_epoch
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.9.18, pytest-7.1.1, pluggy-1.3.0 -- C:\Users\annicet\anaconda3\envs\udacity\python.exe
# cachedir: .pytest_cache
# rootdir: C:\Users\annicet\Projects\Landmark-Classification-Tagging-for-Social-Media
# plugins: anyio-3.5.0
# collecting ... collected 4 items / 3 deselected / 1 selected
#
# src/train.py::test_train_one_epoch PASSED                                [100%]
#
# ============================== warnings summary ===============================
# ..\..\AppData\Roaming\Python\Python39\site-packages\matplotlib\__init__.py:152
# ..\..\AppData\Roaming\Python\Python39\site-packages\matplotlib\__init__.py:152
# ..\..\AppData\Roaming\Python\Python39\site-packages\matplotlib\__init__.py:152
# ..\..\AppData\Roaming\Python\Python39\site-packages\matplotlib\__init__.py:152
# ..\..\AppData\Roaming\Python\Python39\site-packages\matplotlib\__init__.py:152
#   C:\Users\annicet\AppData\Roaming\Python\Python39\site-packages\matplotlib\__init__.py:152: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#     if LooseVersion(module.__version__) < minver:
#
# ..\..\anaconda3\envs\udacity\lib\site-packages\setuptools\_distutils\version.py:345
# ..\..\anaconda3\envs\udacity\lib\site-packages\setuptools\_distutils\version.py:345
# ..\..\anaconda3\envs\udacity\lib\site-packages\setuptools\_distutils\version.py:345
# ..\..\anaconda3\envs\udacity\lib\site-packages\setuptools\_distutils\version.py:345
# ..\..\anaconda3\envs\udacity\lib\site-packages\setuptools\_distutils\version.py:345
#   C:\Users\annicet\anaconda3\envs\udacity\lib\site-packages\setuptools\_distutils\version.py:345: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#     other = LooseVersion(other)
#
# -- Docs: https://docs.pytest.org/en/stable/how-to/capture-warnings.html
# ================ 1 passed, 3 deselected, 10 warnings in 7.00s =================

# %% [markdown]
# Now complete the `valid` function, then run the tests:

# %%
# !pytest -vv src/train.py -k valid_one_epoch
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.9.18, pytest-7.1.1, pluggy-1.3.0 -- C:\Users\annicet\anaconda3\envs\udacity\python.exe
# cachedir: .pytest_cache
# rootdir: C:\Users\annicet\Projects\Landmark-Classification-Tagging-for-Social-Media
# plugins: anyio-3.5.0
# collecting ... collected 4 items / 3 deselected / 1 selected
#
# src/train.py::test_valid_one_epoch PASSED                                [100%]
#
# ============================== warnings summary ===============================
# ..\..\AppData\Roaming\Python\Python39\site-packages\matplotlib\__init__.py:152
# ..\..\AppData\Roaming\Python\Python39\site-packages\matplotlib\__init__.py:152
# ..\..\AppData\Roaming\Python\Python39\site-packages\matplotlib\__init__.py:152
# ..\..\AppData\Roaming\Python\Python39\site-packages\matplotlib\__init__.py:152
# ..\..\AppData\Roaming\Python\Python39\site-packages\matplotlib\__init__.py:152
#   C:\Users\annicet\AppData\Roaming\Python\Python39\site-packages\matplotlib\__init__.py:152: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#     if LooseVersion(module.__version__) < minver:
#
# ..\..\anaconda3\envs\udacity\lib\site-packages\setuptools\_distutils\version.py:345
# ..\..\anaconda3\envs\udacity\lib\site-packages\setuptools\_distutils\version.py:345
# ..\..\anaconda3\envs\udacity\lib\site-packages\setuptools\_distutils\version.py:345
# ..\..\anaconda3\envs\udacity\lib\site-packages\setuptools\_distutils\version.py:345
# ..\..\anaconda3\envs\udacity\lib\site-packages\setuptools\_distutils\version.py:345
#   C:\Users\annicet\anaconda3\envs\udacity\lib\site-packages\setuptools\_distutils\version.py:345: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#     other = LooseVersion(other)
#
# -- Docs: https://docs.pytest.org/en/stable/how-to/capture-warnings.html
# ================ 1 passed, 3 deselected, 10 warnings in 4.59s =================

# %% [markdown]
# Now complete the `optimize` function, then run the tests:

# %%
# !pytest -vv src/train.py -k optimize
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.9.18, pytest-7.1.1, pluggy-1.3.0 -- C:\Users\annicet\anaconda3\envs\udacity\python.exe
# cachedir: .pytest_cache
# rootdir: C:\Users\annicet\Projects\Landmark-Classification-Tagging-for-Social-Media
# plugins: anyio-3.5.0
# collecting ... collected 4 items / 3 deselected / 1 selected
#
# src/train.py::test_optimize PASSED                                       [100%]
#
# ============================== warnings summary ===============================
# ..\..\AppData\Roaming\Python\Python39\site-packages\matplotlib\__init__.py:152
# ..\..\AppData\Roaming\Python\Python39\site-packages\matplotlib\__init__.py:152
# ..\..\AppData\Roaming\Python\Python39\site-packages\matplotlib\__init__.py:152
# ..\..\AppData\Roaming\Python\Python39\site-packages\matplotlib\__init__.py:152
# ..\..\AppData\Roaming\Python\Python39\site-packages\matplotlib\__init__.py:152
#   C:\Users\annicet\AppData\Roaming\Python\Python39\site-packages\matplotlib\__init__.py:152: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#     if LooseVersion(module.__version__) < minver:
#
# ..\..\anaconda3\envs\udacity\lib\site-packages\setuptools\_distutils\version.py:345
# ..\..\anaconda3\envs\udacity\lib\site-packages\setuptools\_distutils\version.py:345
# ..\..\anaconda3\envs\udacity\lib\site-packages\setuptools\_distutils\version.py:345
# ..\..\anaconda3\envs\udacity\lib\site-packages\setuptools\_distutils\version.py:345
# ..\..\anaconda3\envs\udacity\lib\site-packages\setuptools\_distutils\version.py:345
#   C:\Users\annicet\anaconda3\envs\udacity\lib\site-packages\setuptools\_distutils\version.py:345: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#     other = LooseVersion(other)
#
# -- Docs: https://docs.pytest.org/en/stable/how-to/capture-warnings.html
# ================ 1 passed, 3 deselected, 10 warnings in 9.49s =================

# %% [markdown]
# Finally, complete the `test` function then run the tests:

# %%
# !pytest -vv src/train.py -k one_epoch_test
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.9.18, pytest-7.1.1, pluggy-1.3.0 -- C:\Users\annicet\anaconda3\envs\udacity\python.exe
# cachedir: .pytest_cache
# rootdir: C:\Users\annicet\Projects\Landmark-Classification-Tagging-for-Social-Media
# plugins: anyio-3.5.0
# collecting ... collected 4 items / 3 deselected / 1 selected
#
# src/train.py::test_one_epoch_test PASSED                                 [100%]
#
# ============================== warnings summary ===============================
# ..\..\AppData\Roaming\Python\Python39\site-packages\matplotlib\__init__.py:152
# ..\..\AppData\Roaming\Python\Python39\site-packages\matplotlib\__init__.py:152
# ..\..\AppData\Roaming\Python\Python39\site-packages\matplotlib\__init__.py:152
# ..\..\AppData\Roaming\Python\Python39\site-packages\matplotlib\__init__.py:152
# ..\..\AppData\Roaming\Python\Python39\site-packages\matplotlib\__init__.py:152
#   C:\Users\annicet\AppData\Roaming\Python\Python39\site-packages\matplotlib\__init__.py:152: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#     if LooseVersion(module.__version__) < minver:
#
# ..\..\anaconda3\envs\udacity\lib\site-packages\setuptools\_distutils\version.py:345
# ..\..\anaconda3\envs\udacity\lib\site-packages\setuptools\_distutils\version.py:345
# ..\..\anaconda3\envs\udacity\lib\site-packages\setuptools\_distutils\version.py:345
# ..\..\anaconda3\envs\udacity\lib\site-packages\setuptools\_distutils\version.py:345
# ..\..\anaconda3\envs\udacity\lib\site-packages\setuptools\_distutils\version.py:345
#   C:\Users\annicet\anaconda3\envs\udacity\lib\site-packages\setuptools\_distutils\version.py:345: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#     other = LooseVersion(other)
#
# -- Docs: https://docs.pytest.org/en/stable/how-to/capture-warnings.html
# ================ 1 passed, 3 deselected, 10 warnings in 4.58s =================

# %% [markdown]
# ---
# ## <img src="static_images/icons/noun-advance-2109145.png" alt=">" style="width:50px"/> Step 5: Putting everything together
#
# Allright, good job getting here! Now it's time to see if all our hard work pays off. In the following cell we will train your model and validate it against the validation set.
#
# Let's start by defining a few hyperparameters. Feel free to experiment with different values and try to optimize your model:

# %%
batch_size = 256      # size of the minibatch for stochastic gradient descent (or Adam)
valid_size = 0.2       # fraction of the training data to reserve for validation
num_epochs = 120        # number of epochs for training
num_classes = 50       # number of classes. Do not change this
dropout = 0.5          # dropout for our model
learning_rate = 0.001  # Learning rate for SGD (or Adam)
opt = 'adam'            # optimizer. 'sgd' or 'adam'
weight_decay = 0.1     # regularization. Increase this to combat overfitting

# %%
from src.data import get_data_loaders
from src.train import optimize
from src.optimization import get_optimizer, get_loss
from src.model import MyModel

    
# get the data loaders using batch_size and valid_size defined in the previous
# cell
# HINT: do NOT copy/paste the values. Use the variables instead
data_loaders = get_data_loaders(batch_size, valid_size)

# instance model MyModel with num_classes and drouput defined in the previous
# cell
model = MyModel(num_classes, dropout)

# Get the optimizer using get_optimizer and the model you just created, the learning rate,
# the optimizer and the weight decay specified in the previous cell
optimizer = get_optimizer(model, opt, learning_rate, weight_decay)

# Get the loss using get_loss
loss = get_loss()

optimize(
    data_loaders,
    model,
    optimizer,
    loss,
    n_epochs=num_epochs,
    save_path="checkpoints/best_val_loss.pt",
    interactive_tracking=True
)

# %% [markdown]
# ---
# ## <img src="static_images/icons/noun-advance-2109145.png" alt=">" style="width:50px"/> Step 6: testing against the Test Set
#
# > <img src="static_images/icons/noun-info-2558213.png" alt="?" style="width:25px"/> only run this *after* you have completed hyperpameter optimization. Do not optimize hyperparameters by looking at the results on the test set, or you might overfit on the test set (bad, bad, bad)
#
# Run the code cell below to try out your model on the test dataset of landmark images. Ensure that your test accuracy is greater than 50%.

# %%
# load the model that got the best validation accuracy
from src.train import one_epoch_test
from src.model import MyModel
import torch

model = MyModel(num_classes=num_classes, dropout=dropout)

# YOUR CODE HERE: load the weights in 'checkpoints/best_val_loss.pt'
model.load_state_dict(torch.load('checkpoints/best_val_loss.pt'))

# Run test
one_epoch_test(data_loaders['test'], model, loss)
# Out:
# Testing: 100%|████████████████████████████████████| 5/5 [00:07<00:00,  1.46s/it]
# Test Loss: 1.347180
#
#
# Test Accuracy: 66% (837/1250)
# 1.347180390357971

# %% [markdown]
# ---
# ## <img src="static_images/icons/noun-advance-2109145.png" alt=">" style="width:50px"/> Step 7: Export using torchscript
#
# Great job creating your CNN models! Now that you have put in all the hard work of creating accurate classifiers, let's export it so we can use it in our app.
#
# But first, as usual, we need to complete some code!
#
# Open `src/predictor.py` and fill up the missing code, then run the tests:

# %%
# !pytest -vv src/predictor.py
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.9.18, pytest-7.1.1, pluggy-1.3.0 -- C:\Users\annicet\anaconda3\envs\udacity\python.exe
# cachedir: .pytest_cache
# rootdir: C:\Users\annicet\Projects\Landmark-Classification-Tagging-for-Social-Media
# plugins: anyio-3.5.0
# collecting ... collected 1 item
#
# src/predictor.py::test_model_construction PASSED                         [100%]
#
# ============================== warnings summary ===============================
# ..\..\AppData\Roaming\Python\Python39\site-packages\matplotlib\__init__.py:152
# ..\..\AppData\Roaming\Python\Python39\site-packages\matplotlib\__init__.py:152
# ..\..\AppData\Roaming\Python\Python39\site-packages\matplotlib\__init__.py:152
# ..\..\AppData\Roaming\Python\Python39\site-packages\matplotlib\__init__.py:152
# ..\..\AppData\Roaming\Python\Python39\site-packages\matplotlib\__init__.py:152
#   C:\Users\annicet\AppData\Roaming\Python\Python39\site-packages\matplotlib\__init__.py:152: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#     if LooseVersion(module.__version__) < minver:
#
# ..\..\anaconda3\envs\udacity\lib\site-packages\setuptools\_distutils\version.py:345
# ..\..\anaconda3\envs\udacity\lib\site-packages\setuptools\_distutils\version.py:345
# ..\..\anaconda3\envs\udacity\lib\site-packages\setuptools\_distutils\version.py:345
# ..\..\anaconda3\envs\udacity\lib\site-packages\setuptools\_distutils\version.py:345
# ..\..\anaconda3\envs\udacity\lib\site-packages\setuptools\_distutils\version.py:345
#   C:\Users\annicet\anaconda3\envs\udacity\lib\site-packages\setuptools\_distutils\version.py:345: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#     other = LooseVersion(other)
#
# -- Docs: https://docs.pytest.org/en/stable/how-to/capture-warnings.html
# ======================= 1 passed, 10 warnings in 1.25s ========================

# %% [markdown]
# Allright, now we are ready to export our model using our Predictor class:

# %%
# NOTE: you might need to restart the notebook before running this step
# If you get an error about RuntimeError: Can't redefine method: forward on class
# restart your notebook then execute only this cell
from src.predictor import Predictor
from src.helpers import compute_mean_and_std
from src.model import MyModel
from src.data import get_data_loaders
import torch

data_loaders = get_data_loaders(batch_size=1)

# First let's get the class names from our data loaders
class_names = data_loaders["train"].dataset.classes

# Then let's move the model_transfer to the CPU
# (we don't need GPU for inference)
model = MyModel(num_classes=50, dropout=0.5).cpu()
print(MyModel)
# Let's make sure we use the right weights by loading the
# best weights we have found during training
# NOTE: remember to use map_location='cpu' so the weights
# are loaded on the CPU (and not the GPU)

# YOUR CODE HERE
model.load_state_dict(torch.load('checkpoints/best_val_loss.pt', map_location='cpu'))

# Let's wrap our model using the predictor class
mean, std = compute_mean_and_std()
predictor = Predictor(model, class_names, mean, std).cpu()

# Export using torch.jit.script
scripted_predictor = torch.jit.script(predictor)

scripted_predictor.save("checkpoints/original_exported.pt")
# Out:
# Reusing cached mean and std
# Dataset mean: tensor([0.4638, 0.4725, 0.4687]), std: tensor([0.2699, 0.2706, 0.3018])
# <class 'src.model.MyModel'>
# Reusing cached mean and std
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File ~\anaconda3\envs\udacity\lib\inspect.py:868, in findsource(object)
#     867 try:
# --> 868     line = lines[lnum]
#     869 except IndexError:
#
# IndexError: list index out of range
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# File ~\anaconda3\envs\udacity\lib\site-packages\torch\_sources.py:21, in get_source_lines_and_file(obj, error_msg)
#      20     filename = inspect.getsourcefile(obj)
# ---> 21     sourcelines, file_lineno = inspect.getsourcelines(obj)
#      22 except OSError as e:
#
# File ~\anaconda3\envs\udacity\lib\inspect.py:1006, in getsourcelines(object)
#    1005 object = unwrap(object)
# -> 1006 lines, lnum = findsource(object)
#    1008 if istraceback(object):
#
# File ~\anaconda3\envs\udacity\lib\inspect.py:870, in findsource(object)
#     869 except IndexError:
# --> 870     raise OSError('lineno is out of bounds')
#     871 if pat.match(line):
#
# OSError: lineno is out of bounds
#
# The above exception was the direct cause of the following exception:
#
# OSError                                   Traceback (most recent call last)
# Cell In[23], line 32
#      29 predictor = Predictor(model, class_names, mean, std).cpu()
#      31 # Export using torch.jit.script
# ---> 32 scripted_predictor = torch.jit.script(predictor)
#      34 scripted_predictor.save("checkpoints/original_exported.pt")
#
# File ~\anaconda3\envs\udacity\lib\site-packages\torch\jit\_script.py:1265, in script(obj, optimize, _frames_up, _rcb, example_inputs)
#    1263 if isinstance(obj, torch.nn.Module):
#    1264     obj = call_prepare_scriptable_func(obj)
# -> 1265     return torch.jit._recursive.create_script_module(
#    1266         obj, torch.jit._recursive.infer_methods_to_compile
#    1267     )
#    1269 if isinstance(obj, dict):
#    1270     return create_script_dict(obj)
#
# File ~\anaconda3\envs\udacity\lib\site-packages\torch\jit\_recursive.py:454, in create_script_module(nn_module, stubs_fn, share_types, is_tracing)
#     452 if not is_tracing:
#     453     AttributeTypeIsSupportedChecker().check(nn_module)
# --> 454 return create_script_module_impl(nn_module, concrete_type, stubs_fn)
#
# File ~\anaconda3\envs\udacity\lib\site-packages\torch\jit\_recursive.py:516, in create_script_module_impl(nn_module, concrete_type, stubs_fn)
#     513     script_module._concrete_type = concrete_type
#     515 # Actually create the ScriptModule, initializing it with the function we just defined
# --> 516 script_module = torch.jit.RecursiveScriptModule._construct(cpp_module, init_fn)
#     518 # Compile methods if necessary
#     519 if concrete_type not in concrete_type_store.methods_compiled:
#
# File ~\anaconda3\envs\udacity\lib\site-packages\torch\jit\_script.py:594, in RecursiveScriptModule._construct(cpp_module, init_fn)
#     581 """
#     582 Construct a RecursiveScriptModule that's ready for use. PyTorch
#     583 code should use this to construct a RecursiveScriptModule instead
#    (...)
#     591     init_fn:  Lambda that initializes the RecursiveScriptModule passed to it.
#     592 """
#     593 script_module = RecursiveScriptModule(cpp_module)
# --> 594 init_fn(script_module)
#     596 # Finalize the ScriptModule: replace the nn.Module state with our
#     597 # custom implementations and flip the _initializing bit.
#     598 RecursiveScriptModule._finalize_scriptmodule(script_module)
#
# File ~\anaconda3\envs\udacity\lib\site-packages\torch\jit\_recursive.py:494, in create_script_module_impl.<locals>.init_fn(script_module)
#     491     scripted = orig_value
#     492 else:
#     493     # always reuse the provided stubs_fn to infer the methods to compile
# --> 494     scripted = create_script_module_impl(orig_value, sub_concrete_type, stubs_fn)
#     496 cpp_module.setattr(name, scripted)
#     497 script_module._modules[name] = scripted
#
# File ~\anaconda3\envs\udacity\lib\site-packages\torch\jit\_recursive.py:466, in create_script_module_impl(nn_module, concrete_type, stubs_fn)
#     457 """
#     458 Convert an nn.Module to a RecursiveScriptModule.
#     459
#    (...)
#     463     stubs_fn:  Lambda that takes an nn.Module and generates a list of ScriptMethodStubs to compile.
#     464 """
#     465 cpp_module = torch._C._create_module_with_type(concrete_type.jit_type)
# --> 466 method_stubs = stubs_fn(nn_module)
#     467 property_stubs = get_property_stubs(nn_module)
#     468 hook_stubs, pre_hook_stubs = get_hook_stubs(nn_module)
#
# File ~\anaconda3\envs\udacity\lib\site-packages\torch\jit\_recursive.py:735, in infer_methods_to_compile(nn_module)
#     733 stubs = []
#     734 for method in uniqued_methods:
# --> 735     stubs.append(make_stub_from_method(nn_module, method))
#     736 return overload_stubs + stubs
#
# File ~\anaconda3\envs\udacity\lib\site-packages\torch\jit\_recursive.py:66, in make_stub_from_method(nn_module, method_name)
#      57     return func
#      58 # Make sure the name present in the resulting AST will match the name
#      59 # requested here. The only time they don't match is if you do something
#      60 # like:
#    (...)
#      64 # In this case, the actual function object will have the name `_forward`,
#      65 # even though we requested a stub for `forward`.
# ---> 66 return make_stub(func, method_name)
#
# File ~\anaconda3\envs\udacity\lib\site-packages\torch\jit\_recursive.py:51, in make_stub(func, name)
#      49 def make_stub(func, name):
#      50     rcb = _jit_internal.createResolutionCallbackFromClosure(func)
# ---> 51     ast = get_jit_def(func, name, self_name="RecursiveScriptModule")
#      52     return ScriptMethodStub(rcb, ast, func)
#
# File ~\anaconda3\envs\udacity\lib\site-packages\torch\jit\frontend.py:233, in get_jit_def(fn, def_name, self_name, is_classmethod)
#     218 def get_jit_def(fn, def_name, self_name=None, is_classmethod=False):
#     219     """
#     220     Build a JIT AST (TreeView) from the given function.
#     221
#    (...)
#     231         self_name: If this function is a method, what the type name of `self` is.
#     232     """
# --> 233     parsed_def = parse_def(fn)
#     234     type_line = torch.jit.annotations.get_type_line(parsed_def.source)
#     235     fn_def = parsed_def.ast.body[0]
#
# File ~\anaconda3\envs\udacity\lib\site-packages\torch\_sources.py:96, in parse_def(fn)
#      95 def parse_def(fn):
# ---> 96     sourcelines, file_lineno, filename = get_source_lines_and_file(fn, ErrorReport.call_stack())
#      97     sourcelines = normalize_source_lines(sourcelines)
#      98     source = ''.join(sourcelines)
#
# File ~\anaconda3\envs\udacity\lib\site-packages\torch\_sources.py:28, in get_source_lines_and_file(obj, error_msg)
#      26     if error_msg:
#      27         msg += '\n' + error_msg
# ---> 28     raise OSError(msg) from e
#      30 return sourcelines, file_lineno, filename
#
# OSError: Can't get source for <bound method MyModel.forward of MyModel(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (4): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (5): ReLU(inplace=True)
#     (6): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (7): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (8): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): ReLU(inplace=True)
#     (10): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (11): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (12): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace=True)
#     (14): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (15): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=1)
#   (classifier): Sequential(
#     (0): Dropout(p=0.5, inplace=False)
#     (1): Linear(in_features=512, out_features=256, bias=True)
#     (2): ReLU(inplace=True)
#     (3): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (4): Dropout(p=0.5, inplace=False)
#     (5): Linear(in_features=256, out_features=50, bias=True)
#     (6): LogSoftmax(dim=1)
#   )
# )>. TorchScript requires source access in order to carry out compilation, make sure original .py files are available.

# %% [markdown]
# Now let's make sure the exported model has the same performance as the original one, by reloading it and testing it. The Predictor class takes different inputs than the non-wrapped model, so we have to use a specific test loop:

# %%
import torch

# Load using torch.jit.load
model_reloaded =  torch.jit.load("checkpoints/original_exported.pt")

# %%
from src.predictor import predictor_test

pred, truth = predictor_test(data_loaders['test'], model_reloaded)
# Out:
#   0%|                                                  | 0/1250 [00:00<?, ?it/s]code/__torch__/torchvision/transforms/functional.py:188: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   0%|                                          | 1/1250 [00:00<04:50,  4.30it/s]C:\Users\arnit\anaconda3\envs\PyTorch\lib\site-packages\torch\nn\modules\module.py:1501: UserWarning: operator () profile_node %386 : int = prim::profile_ivalue(%out_dtype.1)
#  does not have profile information (Triggered internally at C:\cb\pytorch_1000000000000\work\third_party\nvfuser\csrc\graph_fuser.cpp:108.)
#   return forward_call(*args, **kwargs)
# code/__torch__/torchvision/transforms/functional.py:188: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   0%|                                          | 2/1250 [00:01<12:46,  1.63it/s]code/__torch__/torchvision/transforms/functional.py:188: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
# code/__torch__/torchvision/transforms/functional.py:188: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
# code/__torch__/torchvision/transforms/functional.py:188: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
# code/__torch__/torchvision/transforms/functional.py:188: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   0%|▏                                         | 6/1250 [00:01<03:21,  6.17it/s]code/__torch__/torchvision/transforms/functional.py:188: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
# code/__torch__/torchvision/transforms/functional.py:188: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
# code/__torch__/torchvision/transforms/functional.py:188: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
# code/__torch__/torchvision/transforms/functional.py:188: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   1%|▎                                        | 10/1250 [00:01<01:53, 10.89it/s]code/__torch__/torchvision/transforms/functional.py:188: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
# code/__torch__/torchvision/transforms/functional.py:188: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
# code/__torch__/torchvision/transforms/functional.py:188: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
# code/__torch__/torchvision/transforms/functional.py:188: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   1%|▍                                        | 14/1250 [00:01<01:19, 15.53it/s]code/__torch__/torchvision/transforms/functional.py:188: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
# code/__torch__/torchvision/transforms/functional.py:188: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
# code/__torch__/torchvision/transforms/functional.py:188: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
# code/__torch__/torchvision/transforms/functional.py:188: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   1%|▌                                        | 18/1250 [00:01<01:03, 19.52it/s]code/__torch__/torchvision/transforms/functional.py:188: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
# code/__torch__/torchvision/transforms/functional.py:188: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
# code/__torch__/torchvision/transforms/functional.py:188: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
# code/__torch__/torchvision/transforms/functional.py:188: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   2%|▋                                        | 22/1250 [00:01<00:53, 22.98it/s]code/__torch__/torchvision/transforms/functional.py:188: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
# code/__torch__/torchvision/transforms/functional.py:188: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
# code/__torch__/torchvision/transforms/functional.py:188: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
# code/__torch__/torchvision/transforms/functional.py:188: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   2%|▊                                        | 26/1250 [00:01<00:48, 25.37it/s]code/__torch__/torchvision/transforms/functional.py:188: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
# code/__torch__/torchvision/transforms/functional.py:188: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
# code/__torch__/torchvision/transforms/functional.py:188: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
# code/__torch__/torchvision/transforms/functional.py:188: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   2%|▉                                        | 30/1250 [00:01<00:44, 27.71it/s]code/__torch__/torchvision/transforms/functional.py:188: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
# code/__torch__/torchvision/transforms/functional.py:188: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
# code/__torch__/torchvision/transforms/functional.py:188: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
# code/__torch__/torchvision/transforms/functional.py:188: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   3%|█                                        | 34/1250 [00:02<00:42, 28.67it/s]code/__torch__/torchvision/transforms/functional.py:188: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
# code/__torch__/torchvision/transforms/functional.py:188: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
# code/__torch__/torchvision/transforms/functional.py:188: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
# code/__torch__/torchvision/transforms/functional.py:188: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   3%|█▏                                       | 38/1250 [00:02<00:42, 28.62it/s]code/__torch__/torchvision/transforms/functional.py:188: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
# code/__torch__/torchvision/transforms/functional.py:188: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
# code/__torch__/torchvision/transforms/functional.py:188: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
# code/__torch__/torchvision/transforms/functional.py:188: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   3%|█▍                                       | 42/1250 [00:02<00:42, 28.54it/s]code/__torch__/torchvision/transforms/functional.py:188: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
# code/__torch__/torchvision/transforms/functional.py:188: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
# code/__torch__/torchvision/transforms/functional.py:188: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
# code/__torch__/torchvision/transforms/functional.py:188: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   4%|█▌                                       | 46/1250 [00:02<00:41, 29.29it/s]code/__torch__/torchvision/transforms/functional.py:188: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
# code/__torch__/torchvision/transforms/functional.py:188: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
# code/__torch__/torchvision/transforms/functional.py:188: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
# code/__torch__/torchvision/transforms/functional.py:188: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   4%|█▋                                       | 50/1250 [00:02<00:39, 30.06it/s]code/__torch__/torchvision/transforms/functional.py:188: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
# code/__torch__/torchvision/transforms/functional.py:188: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
# code/__torch__/torchvision/transforms/functional.py:188: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
# code/__torch__/torchvision/transforms/functional.py:188: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   4%|█▊                                       | 54/1250 [00:02<00:39, 30.45it/s]code/__torch__/torchvision/transforms/functional.py:188: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
# code/__torch__/torchvision/transforms/functional.py:188: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
# code/__torch__/torchvision/transforms/functional.py:188: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
# code/__torch__/torchvision/transforms/functional.py:188: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   5%|█▉                                       | 58/1250 [00:02<00:38, 31.18it/s]code/__torch__/torchvision/transforms/functional.py:188: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
# code/__torch__/torchvision/transforms/functional.py:188: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
# code/__torch__/torchvision/transforms/functional.py:188: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
# code/__torch__/torchvision/transforms/functional.py:188: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   5%|██                                       | 62/1250 [00:02<00:37, 31.70it/s]code/__torch__/torchvision/transforms/functional.py:188: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
# code/__torch__/torchvision/transforms/functional.py:188: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
# code/__torch__/torchvision/transforms/functional.py:188: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
# code/__torch__/torchvision/transforms/functional.py:188: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   5%|██▏                                      | 66/1250 [00:03<00:37, 31.61it/s]code/__torch__/torchvision/transforms/functional.py:188: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
# code/__torch__/torchvision/transforms/functional.py:188: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
# ...
#  98%|██████████████████████████████████████▎| 1228/1250 [00:39<00:00, 32.28it/s]code/__torch__/torchvision/transforms/functional.py:188: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
# code/__torch__/torchvision/transforms/functional.py:188: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
# code/__torch__/torchvision/transforms/functional.py:188: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
# code/__torch__/torchvision/transforms/functional.py:188: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#  99%|██████████████████████████████████████▍| 1232/1250 [00:39<00:00, 31.80it/s]code/__torch__/torchvision/transforms/functional.py:188: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
# code/__torch__/torchvision/transforms/functional.py:188: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
# code/__torch__/torchvision/transforms/functional.py:188: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
# code/__torch__/torchvision/transforms/functional.py:188: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#  99%|██████████████████████████████████████▌| 1236/1250 [00:39<00:00, 31.24it/s]code/__torch__/torchvision/transforms/functional.py:188: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
# code/__torch__/torchvision/transforms/functional.py:188: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
# code/__torch__/torchvision/transforms/functional.py:188: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
# code/__torch__/torchvision/transforms/functional.py:188: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#  99%|██████████████████████████████████████▋| 1240/1250 [00:39<00:00, 31.89it/s]code/__torch__/torchvision/transforms/functional.py:188: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
# code/__torch__/torchvision/transforms/functional.py:188: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
# code/__torch__/torchvision/transforms/functional.py:188: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
# code/__torch__/torchvision/transforms/functional.py:188: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
# 100%|██████████████████████████████████████▊| 1244/1250 [00:39<00:00, 33.16it/s]code/__torch__/torchvision/transforms/functional.py:188: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
# code/__torch__/torchvision/transforms/functional.py:188: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
# code/__torch__/torchvision/transforms/functional.py:188: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
# code/__torch__/torchvision/transforms/functional.py:188: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
# 100%|██████████████████████████████████████▉| 1248/1250 [00:39<00:00, 33.16it/s]code/__torch__/torchvision/transforms/functional.py:188: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
# code/__torch__/torchvision/transforms/functional.py:188: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#
# 100%|███████████████████████████████████████| 1250/1250 [00:40<00:00, 31.22it/s]
# Accuracy: 0.5528

# %% [markdown]
# Finally, let's have a look at the confusion matrix of the model we are going to use in production:

# %%
from src.helpers import plot_confusion_matrix

plot_confusion_matrix(pred, truth)
